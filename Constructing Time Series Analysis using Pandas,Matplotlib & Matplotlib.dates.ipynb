# %%
# Importing all the relevant libaries which will be used for analysis. 

import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
# Use the read_csv function to return the file which we will be analysing and display it as a dataframe.
#We also add the in the file path for file to the read_csv function.

df_tesla = pd.read_csv (r'C:\Users\4ben\Downloads\Google+Trends+Data+Viz+(start)\Google Trends Data Viz (start)\TESLA Search Trend vs Price.csv')
df_tesla
# Out:
#           MONTH  TSLA_WEB_SEARCH  TSLA_USD_CLOSE
# 0    2010-06-01                3        4.766000
# 1    2010-07-01                3        3.988000
# 2    2010-08-01                2        3.896000
# 3    2010-09-01                2        4.082000
# 4    2010-10-01                2        4.368000
# ..          ...              ...             ...
# 119  2020-05-01               16      167.000000
# 120  2020-06-01               17      215.962006
# 121  2020-07-01               24      286.152008
# 122  2020-08-01               23      498.320007
# 123  2020-09-01               31      407.339996
#
# [124 rows x 3 columns]

# %%
#Find largest value (31) in "TSLA_WEB_SEARCH" column. 
maxx = df_tesla.TSLA_WEB_SEARCH.max()
maxx
# Out:
# 31

# %%
#Find smallest value (2) in "TSLA_WEB_SEARCH" column
mimm = df_tesla.TSLA_WEB_SEARCH.min()
mimm
# Out:
# 2

# %%
print(f"Largest value for Tesla Web Search is: {maxx}")
# Out:
# Largest value for Tesla Web Search is: 31

# %%
print(f"Smallest value for Tesla Web Search is: {mimm}")
# Out:
# Smallest value for Tesla Web Search is: 2

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

df_tesla = pd.read_csv (r'C:\Users\4ben\Downloads\Google+Trends+Data+Viz+(start)\Google Trends Data Viz (start)\TESLA Search Trend vs Price.csv')
df_tesla

df_tesla.describe() # Using describe function to display all key summary statistics.
# Out:
#        TSLA_WEB_SEARCH  TSLA_USD_CLOSE
# count       124.000000      124.000000
# mean          8.725806       50.962145
# std           5.870332       65.908389
# min           2.000000        3.896000
# 25%           3.750000        7.352500
# 50%           8.000000       44.653000
# 75%          12.000000       58.991999
# max          31.000000      498.320007

# %%
df_unemployment = pd.read_csv (r'C:\Users\4ben\Downloads\Google+Trends+Data+Viz+(start)\Google Trends Data Viz (start)\UE Benefits Search vs UE Rate 2004-19.csv')
df_unemployment
# Out:
#        MONTH  UE_BENEFITS_WEB_SEARCH  UNRATE
# 0    2004-01                      34     5.7
# 1    2004-02                      33     5.6
# 2    2004-03                      25     5.8
# 3    2004-04                      29     5.6
# 4    2004-05                      23     5.6
# ..       ...                     ...     ...
# 176  2018-09                      14     3.7
# 177  2018-10                      15     3.8
# 178  2018-11                      16     3.7
# 179  2018-12                      17     3.9
# 180  2019-01                      21     4.0
#
# [181 rows x 3 columns]

# %%
# Creating a variable called lowestt which returns the lowest value in "UE_BENEFITS_WEB_SEARCH" function
lowestt = df_unemployment.UE_BENEFITS_WEB_SEARCH.min() 

lowestt
# Out:
# 14

# %%
#Using an input function and inserting the variable created in line 14.
print(f"the smallest is {lowestt}")
# Out:
# the smallest is 14

# %%
btc_price = pd.read_csv (r'C:\Users\4ben\Downloads\Google+Trends+Data+Viz+(start)\Google Trends Data Viz (start)\Daily Bitcoin Price.csv')
btc_price
#btc_price dataframe has 2204 rows and 3 columns.
# Out:
#             DATE         CLOSE        VOLUME
# 0     2014-09-17    457.334015  2.105680e+07
# 1     2014-09-18    424.440002  3.448320e+07
# 2     2014-09-19    394.795990  3.791970e+07
# 3     2014-09-20    408.903992  3.686360e+07
# 4     2014-09-21    398.821014  2.658010e+07
# ...          ...           ...           ...
# 2199  2020-09-24  10745.548828  2.301754e+10
# 2200  2020-09-25  10702.290039  2.123255e+10
# 2201  2020-09-26  10754.437500  1.810501e+10
# 2202  2020-09-27  10774.426758  1.801688e+10
# 2203  2020-09-28  10912.536133  2.122653e+10
#
# [2204 rows x 3 columns]

# %%
btc_search = pd.read_csv (r'C:\Users\4ben\Downloads\Google+Trends+Data+Viz+(start)\Google Trends Data Viz (start)\Bitcoin Search Trend.csv')
btc_search
# Out:
#       MONTH  BTC_NEWS_SEARCH
# 0   2014-09                5
# 1   2014-10                4
# 2   2014-11                4
# 3   2014-12                4
# 4   2015-01                5
# ..      ...              ...
# 68  2020-05               22
# 69  2020-06               13
# 70  2020-07               14
# 71  2020-08               16
# 72  2020-09               13
#
# [73 rows x 2 columns]

# %%
#Finding out the highest value in the "BTC_NEWS_SEARCH" column from the "btc_search" dataframe.
Largest_Search = btc_search.BTC_NEWS_SEARCH.max()
Largest_Search
# Out:
# 100

# %%
#Check if there are any blank/missing values in "df_tesla" dataframe.

Blank_value_in_tesla = df_tesla.isna().values.any()  
Blank_value_in_tesla
# Out:
# False

# %%
print(f"Are there any blank values in tesla?:{Blank_value_in_tesla}")
# Out:
# Are there any blank values in tesla?:False

# %%
blank_unemployment = df_unemployment.isna().values.any()
blank_unemployment
# Out:
# False

# %%
#Searching for any blank values in a dataframe
blank_btc_price = btc_price.isna().values.any()
blank_btc_price
#We get "True" so there are some missing values in the "btc_price" dataframe.
# Out:
# True

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd


btc_search = pd.read_csv (r'C:\Users\4ben\Downloads\Google+Trends+Data+Viz+(start)\Google Trends Data Viz (start)\Bitcoin Search Trend.csv')
btc_search


btc_price = pd.read_csv (r'C:\Users\4ben\Downloads\Google+Trends+Data+Viz+(start)\Google Trends Data Viz (start)\Daily Bitcoin Price.csv')
btc_price



df_tesla = pd.read_csv (r'C:\Users\4ben\Downloads\Google+Trends+Data+Viz+(start)\Google Trends Data Viz (start)\TESLA Search Trend vs Price.csv')
df_tesla

df_unemployment = pd.read_csv (r'C:\Users\4ben\Downloads\Google+Trends+Data+Viz+(start)\Google Trends Data Viz (start)\UE Benefits Search vs UE Rate 2004-19.csv')
df_unemployment


btc_price.isna().values.sum() # Counting how many missing values we have in the "btc_price" dataframe.
# Out:
# 2

# %%
#Find the number of missing values in the "btc_price" dataframe
btc_price.isna().values.sum()
# Out:
# 2

# %%
#To find the row where the missing values exist:

btc_price[btc_price.VOLUME.isna()]

#One missing value is in the "CLOSE" column and the other is in the "VOLUME" column.
# Out:
#             DATE  CLOSE  VOLUME
# 2148  2020-08-04    NaN     NaN

# %%
#One missing value is in the "CLOSE" column and the other is in the "VOLUME" column.

btc_price[btc_price.CLOSE.isna()]
# Out:
#             DATE  CLOSE  VOLUME
# 2148  2020-08-04    NaN     NaN

# %%
#Remove any missing values in a dataframe. We use inplace function to overwrite our dataframe and make the change permanent.
btc_price.dropna(inplace=True)

# Another check to make sure that the missing values have been removed from the "btc_price" dataframe.
btc_price.isna().values.sum() # 0 is returned which means the missing values have been removed.
# Out:
# 0

# %%
df_tesla
# Out:
#           MONTH  TSLA_WEB_SEARCH  TSLA_USD_CLOSE
# 0    2010-06-01                3        4.766000
# 1    2010-07-01                3        3.988000
# 2    2010-08-01                2        3.896000
# 3    2010-09-01                2        4.082000
# 4    2010-10-01                2        4.368000
# ..          ...              ...             ...
# 119  2020-05-01               16      167.000000
# 120  2020-06-01               17      215.962006
# 121  2020-07-01               24      286.152008
# 122  2020-08-01               23      498.320007
# 123  2020-09-01               31      407.339996
#
# [124 rows x 3 columns]

# %%
#Before we begin our time series analysis we must confirm that we have the correct datatype for "MONTH" column in the "df_tesla" dataframe. 
#We must convert the data from "Month" column into Datetime objects.

type(df_tesla["MONTH"])
# Out:
# pandas.core.series.Series

# %%
type(df_tesla.MONTH[0])
# Out:
# str

# %%
#Creating a new variable where the Month column datatype has been converted to datetime.
df_tesla.MONTH = pd.to_datetime(df_tesla.MONTH)

# %%
#Now the month is converted to the datetime object datatype which is what we want & we'll do the same for the other dataframes.
df_tesla.MONTH
# Out:
# 0     2010-06-01
# 1     2010-07-01
# 2     2010-08-01
# 3     2010-09-01
# 4     2010-10-01
#          ...
# 119   2020-05-01
# 120   2020-06-01
# 121   2020-07-01
# 122   2020-08-01
# 123   2020-09-01
# Name: MONTH, Length: 124, dtype: datetime64[ns]

# %%
btc_price.DATE = pd.to_datetime(btc_price.DATE) # Converting "Date" column to datetime datatype objects.

# %%
btc_price.DATE
# Out:
# 0      2014-09-17
# 1      2014-09-18
# 2      2014-09-19
# 3      2014-09-20
# 4      2014-09-21
#           ...
# 2199   2020-09-24
# 2200   2020-09-25
# 2201   2020-09-26
# 2202   2020-09-27
# 2203   2020-09-28
# Name: DATE, Length: 2203, dtype: datetime64[ns]

# %%
df_unemployment.MONTH = pd.to_datetime(df_unemployment.MONTH)
df_unemployment.MONTH # Converting the "Month" to datetime datatype objects.
# Out:
# 0     2004-01-01
# 1     2004-02-01
# 2     2004-03-01
# 3     2004-04-01
# 4     2004-05-01
#          ...
# 176   2018-09-01
# 177   2018-10-01
# 178   2018-11-01
# 179   2018-12-01
# 180   2019-01-01
# Name: MONTH, Length: 181, dtype: datetime64[ns]

# %%
btc_search.MONTH = pd.to_datetime(btc_search.MONTH)
btc_search.MONTH
# Out:
# 0    2014-09-01
# 1    2014-10-01
# 2    2014-11-01
# 3    2014-12-01
# 4    2015-01-01
#         ...
# 68   2020-05-01
# 69   2020-06-01
# 70   2020-07-01
# 71   2020-08-01
# 72   2020-09-01
# Name: MONTH, Length: 73, dtype: datetime64[ns]

# %%
#Turning daily data from "btc_price" into data which shows the last available price of the month.
#We use a resample function to do this.
btc_monthly_end = btc_price.resample("M", on="DATE").last()

# %%
btc_monthly_end
# Out:
#                  DATE         CLOSE        VOLUME
# DATE
# 2014-09-30 2014-09-30    386.944000  3.470730e+07
# 2014-10-31 2014-10-31    338.321014  1.254540e+07
# 2014-11-30 2014-11-30    378.046997  9.194440e+06
# 2014-12-31 2014-12-31    320.192993  1.394290e+07
# 2015-01-31 2015-01-31    217.464005  2.334820e+07
# ...               ...           ...           ...
# 2020-05-31 2020-05-31   9461.058594  2.777329e+10
# 2020-06-30 2020-06-30   9137.993164  1.573580e+10
# 2020-07-31 2020-07-31  11323.466797  2.316047e+10
# 2020-08-31 2020-08-31  11680.820313  2.228593e+10
# 2020-09-30 2020-09-28  10912.536133  2.122653e+10
#
# [73 rows x 3 columns]

# %%
#If we wanted the average price over the course of the month we would use:
   # btc_monthly_average = btc_price.resample("M", on="DATE").mean()

# %% [markdown]
# # Plot the Tesla stock price against the Tesla search volume using a line chart and two different vertical axes

# %%
df_tesla
# Out:
#          MONTH  TSLA_WEB_SEARCH  TSLA_USD_CLOSE
# 0   2010-06-01                3        4.766000
# 1   2010-07-01                3        3.988000
# 2   2010-08-01                2        3.896000
# 3   2010-09-01                2        4.082000
# 4   2010-10-01                2        4.368000
# ..         ...              ...             ...
# 119 2020-05-01               16      167.000000
# 120 2020-06-01               17      215.962006
# 121 2020-07-01               24      286.152008
# 122 2020-08-01               23      498.320007
# 123 2020-09-01               31      407.339996
#
# [124 rows x 3 columns]

# %%
#increases size and resolution
plt.figure(figsize=(14,8), dpi=120)

plt.title("Tesla Web Search vs Price", fontsize=18) #Title of graph and fontsize of title


# Increase the size and rotate the labels on the x-axis
plt.xticks(fontsize=14, rotation=45)


ax1 = plt.gca() # This line of code ALWAYS refers to THE FIRST VERTICAL AXIS ON LEFT HAND SIDE of graph.
ax2 = ax1.twinx() #We are adding a y-axis label as the secondary axis on our graph so we add in this line of code to create a twin axes sharing one horizontal axis.

ax1.set_ylabel("TSLA STOCK PRICE", color = "green") # Choosing the name + color of title on the first horizontal axis on left hand side.
ax2.set_ylabel("Search Trend") #Choosing the name of the 2nd horizontal axis on right hand side.

ax1.plot(df_tesla.MONTH, df_tesla.TSLA_USD_CLOSE, color = "green", linestyle = "dashed")
ax2.plot(df_tesla.MONTH, df_tesla.TSLA_WEB_SEARCH)

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import matplotlib.dates as mdates #Matplotlib dates lets us add tick marks to the horizontal axis

# %%
#The next three lines of code are for constructing major & minor ticks on the horizontal axis which shows time(years) in our graph for U/E rate and Monthly search of US Benefits.
years = mdates.YearLocator()
months = mdates.MonthLocator()
years_fmt = mdates.DateFormatter('%Y')

btc_search = pd.read_csv (r'C:\Users\4ben\Downloads\Google+Trends+Data+Viz+(start)\Google Trends Data Viz (start)\Bitcoin Search Trend.csv')
btc_search


btc_price = pd.read_csv (r'C:\Users\4ben\Downloads\Google+Trends+Data+Viz+(start)\Google Trends Data Viz (start)\Daily Bitcoin Price.csv')
btc_price



df_tesla = pd.read_csv (r'C:\Users\4ben\Downloads\Google+Trends+Data+Viz+(start)\Google Trends Data Viz (start)\TESLA Search Trend vs Price.csv')
df_tesla

df_unemployment = pd.read_csv (r'C:\Users\4ben\Downloads\Google+Trends+Data+Viz+(start)\Google Trends Data Viz (start)\UE Benefits Search vs UE Rate 2004-19.csv')
df_unemployment

df_unemployment.MONTH = pd.to_datetime(df_unemployment.MONTH)
df_unemployment.MONTH
# Out:
# 0     2004-01-01
# 1     2004-02-01
# 2     2004-03-01
# 3     2004-04-01
# 4     2004-05-01
#          ...
# 176   2018-09-01
# 177   2018-10-01
# 178   2018-11-01
# 179   2018-12-01
# 180   2019-01-01
# Name: MONTH, Length: 181, dtype: datetime64[ns]

# %%
plt.figure(figsize=(14,8), dpi=120)
plt.title('Monthly Search of "Unemployment Benefits" in the U.S. vs the U/E Rate', fontsize=18)
plt.yticks(fontsize=14)
plt.xticks(fontsize=14, rotation=45)
 
ax1 = plt.gca()
ax2 = ax1.twinx()
 
ax1.set_ylabel('FRED U/E Rate', color='purple', fontsize=14)
ax2.set_ylabel('Search Trend', color='skyblue', fontsize=14)
 
ax1.xaxis.set_major_locator(years)
ax1.xaxis.set_major_formatter(years_fmt)
ax1.xaxis.set_minor_locator(months)
 
ax1.set_ylim(bottom=3, top=10.5)
ax1.set_xlim([df_unemployment.MONTH.min(), df_unemployment.MONTH.max()])
 
# Show the grid lines as dark grey lines
ax1.grid(color='grey', linestyle='--')
 
# Change the dataset used
ax1.plot(df_unemployment.MONTH, df_unemployment.UNRATE, 
         color='purple', linewidth=3, linestyle='--')
ax2.plot(df_unemployment.MONTH, df_unemployment.UE_BENEFITS_WEB_SEARCH, 
         color='skyblue', linewidth=3)
 
plt.show()

# %%
import matplotlib.dates as mdates
years = mdates.YearLocator()
months = mdates.MonthLocator()
years_fmt = mdates.DateFormatter("%Y")

# %%
df_unemployment
# Out:
#          MONTH  UE_BENEFITS_WEB_SEARCH  UNRATE
# 0   2004-01-01                      34     5.7
# 1   2004-02-01                      33     5.6
# 2   2004-03-01                      25     5.8
# 3   2004-04-01                      29     5.6
# 4   2004-05-01                      23     5.6
# ..         ...                     ...     ...
# 176 2018-09-01                      14     3.7
# 177 2018-10-01                      15     3.8
# 178 2018-11-01                      16     3.7
# 179 2018-12-01                      17     3.9
# 180 2019-01-01                      21     4.0
#
# [181 rows x 3 columns]

# %%
plt.figure(figsize=(14,8), dpi=120)
plt.title('Rolling Monthly US "Unemployment Benefits" Web Searches vs UNRATE', fontsize=18)
plt.yticks(fontsize=14)
plt.xticks(fontsize=14, rotation=45)
 
ax1 = plt.gca()
ax2 = ax1.twinx()
 
ax1.xaxis.set_major_locator(years)
ax1.xaxis.set_major_formatter(years_fmt)
ax1.xaxis.set_minor_locator(months)
 
ax1.set_ylabel('FRED U/E Rate', color='purple', fontsize=16)
ax2.set_ylabel('Search Trend', color='skyblue', fontsize=16)
 
ax1.set_ylim(bottom=3, top=10.5)
ax1.set_xlim([df_unemployment.MONTH[0], df_unemployment.MONTH.max()])
 
# Calculate the rolling average over a 6 month window to smooth out the time series data and remove volatile up/down spikes to more easily see what the graph is showing us.
roll_df = df_unemployment[['UE_BENEFITS_WEB_SEARCH', 'UNRATE']].rolling(window=6).mean()
 
ax1.plot(df_unemployment.MONTH, roll_df.UNRATE, 'purple', linewidth=3, linestyle='-.')
ax2.plot(df_unemployment.MONTH, roll_df.UE_BENEFITS_WEB_SEARCH, 'skyblue', linewidth=3)
 
plt.show()

# %%
df_ue_2020 = pd.read_csv (r'C:\Users\4ben\Downloads\Google+Trends+Data+Viz+(start)\Google Trends Data Viz (start)\UE Benefits Search vs UE Rate 2004-20.csv')
df_ue_2020
df_ue_2020.MONTH = pd.to_datetime(df_ue_2020.MONTH)

# %%
plt.figure(figsize=(14,8), dpi=120)
plt.yticks(fontsize=14)
plt.xticks(fontsize=14, rotation=45)
plt.title('Monthly US "Unemployment Benefits" Web Search vs UNRATE incl 2020', fontsize=18)
 
ax1 = plt.gca()
ax2 = ax1.twinx()
 
ax1.set_ylabel('FRED U/E Rate', color='purple', fontsize=16)
ax2.set_ylabel('Search Trend', color='skyblue', fontsize=16)
 
ax1.set_xlim([df_ue_2020.MONTH.min(), df_ue_2020.MONTH.max()])
 
ax1.plot(df_ue_2020.MONTH, df_ue_2020.UNRATE, 'purple', linewidth=3)
ax2.plot(df_ue_2020.MONTH, df_ue_2020.UE_BENEFITS_WEB_SEARCH, 'skyblue', linewidth=3)
 
plt.show()
